# %%
import numpy as np

# %%
import pandas as pd

# %%
import datetime as dt

# %%
from matplotlib import pyplot as plt

# %%
import seaborn as sns

# %%
customer=pd.read_csv('Customer.csv')
customer
# Out:
#       customer_Id         DOB Gender  city_code
# 0          268408  02-01-1970      M        4.0
# 1          269696  07-01-1970      F        8.0
# 2          268159  08-01-1970      F        8.0
# 3          270181  10-01-1970      F        2.0
# 4          268073  11-01-1970      M        1.0
# ...           ...         ...    ...        ...
# 5642       274474  19-12-1992      M        2.0
# 5643       267666  24-12-1992      M        6.0
# 5644       270476  25-12-1992      F        3.0
# 5645       269626  27-12-1992      F        5.0
# 5646       274308  29-12-1992      F        5.0
#
# [5647 rows x 4 columns]

# %%
customer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5647 entries, 0 to 5646
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   customer_Id  5647 non-null   int64
#  1   DOB          5647 non-null   object
#  2   Gender       5645 non-null   object
#  3   city_code    5645 non-null   float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 176.6+ KB

# %%
customer['customer_Id']=customer['customer_Id'].astype('float64')
customer['DOB']= pd.to_datetime(customer['DOB'], format='%m-%d-%y')

# %%
customer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5647 entries, 0 to 5646
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   customer_Id  5647 non-null   float64
#  1   DOB          5647 non-null   datetime64[ns]
#  2   Gender       5645 non-null   object
#  3   city_code    5645 non-null   float64
# dtypes: datetime64[ns](1), float64(2), object(1)
# memory usage: 176.6+ KB

# %%
customer.head(10)
# Out:
#    customer_Id        DOB Gender  city_code
# 0     268408.0 1970-02-01      M        4.0
# 1     269696.0 1970-07-01      F        8.0
# 2     268159.0 1970-08-01      F        8.0
# 3     270181.0 1970-10-01      F        2.0
# 4     268073.0 1970-11-01      M        1.0
# 5     273216.0 1970-01-15      F        5.0
# 6     266929.0 1970-01-15      M        8.0
# 7     275152.0 1970-01-16      M        4.0
# 8     275034.0 1970-01-18      F        4.0
# 9     273966.0 1970-01-21      M        8.0

# %%
productinfo=pd.read_csv('prod_cat_info.csv')
productinfo
# Out:
#     prod_cat_code          prod_cat  prod_sub_cat_code          prod_subcat
# 0               1          Clothing                  4                 Mens
# 1               1          Clothing                  1                Women
# 2               1          Clothing                  3                 Kids
# 3               2          Footwear                  1                 Mens
# 4               2          Footwear                  3                Women
# 5               2          Footwear                  4                 Kids
# 6               3       Electronics                  4              Mobiles
# 7               3       Electronics                  5            Computers
# 8               3       Electronics                  8  Personal Appliances
# 9               3       Electronics                  9              Cameras
# 10              3       Electronics                 10      Audio and video
# ...

# %%
productinfo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   prod_cat_code      23 non-null     int64
#  1   prod_cat           23 non-null     object
#  2   prod_sub_cat_code  23 non-null     int64
#  3   prod_subcat        23 non-null     object
# dtypes: int64(2), object(2)
# memory usage: 864.0+ bytes

# %%
transactions=pd.read_csv('Transactions.csv')
transactions
# Out:
#        transaction_id  cust_id   tran_date  prod_subcat_code  prod_cat_code  \
# 0         80712190438   270351  28-02-2014                 1              1
# 1         29258453508   270384  27-02-2014                 5              3
# 2         51750724947   273420  24-02-2014                 6              5
# 3         93274880719   271509  24-02-2014                11              6
# 4         51750724947   273420  23-02-2014                 6              5
# ...               ...      ...         ...               ...            ...
# 23048     94340757522   274550  25-01-2011                12              5
# 23049     89780862956   270022  25-01-2011                 4              1
# 23050     85115299378   271020  25-01-2011                 2              6
# 23051     72870271171   270911  25-01-2011                11              5
# 23052     77960931771   271961  25-01-2011                11              5
#
#        Qty  Rate      Tax  total_amt Store_type
# ...

# %%
transactions.rename(columns={'cust_id':'customer_Id','prod_subcat_code':'prod_sub_cat_code',},inplace=True)

# %%
transactions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23053 entries, 0 to 23052
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   transaction_id     23053 non-null  int64
#  1   customer_Id        23053 non-null  int64
#  2   tran_date          23053 non-null  object
#  3   prod_sub_cat_code  23053 non-null  int64
#  4   prod_cat_code      23053 non-null  int64
#  5   Qty                23053 non-null  int64
#  6   Rate               23053 non-null  int64
#  7   Tax                23053 non-null  float64
#  8   total_amt          23053 non-null  float64
#  9   Store_type         23053 non-null  object
# dtypes: float64(2), int64(6), object(2)
# memory usage: 1.8+ MB

# %%
transactions['customer_Id']=transactions['customer_Id'].astype('float64')

transactions['tran_date']=transactions['tran_date'].apply(lambda x:pd.to_datetime(x))

# %%
transactions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23053 entries, 0 to 23052
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   transaction_id     23053 non-null  int64
#  1   customer_Id        23053 non-null  float64
#  2   tran_date          23053 non-null  datetime64[ns]
#  3   prod_sub_cat_code  23053 non-null  int64
#  4   prod_cat_code      23053 non-null  int64
#  5   Qty                23053 non-null  int64
#  6   Rate               23053 non-null  int64
#  7   Tax                23053 non-null  float64
#  8   total_amt          23053 non-null  float64
#  9   Store_type         23053 non-null  object
# dtypes: datetime64[ns](1), float64(3), int64(5), object(1)
# memory usage: 1.8+ MB

# %%
transactions.head(10)
# Out:
#    transaction_id  customer_Id  tran_date  prod_sub_cat_code  prod_cat_code  \
# 0     80712190438     270351.0 2014-02-28                  1              1
# 1     29258453508     270384.0 2014-02-27                  5              3
# 2     51750724947     273420.0 2014-02-24                  6              5
# 3     93274880719     271509.0 2014-02-24                 11              6
# 4     51750724947     273420.0 2014-02-23                  6              5
# 5     97439039119     272357.0 2014-02-23                  8              3
# 6     45649838090     273667.0 2014-02-22                 11              6
# 7     22643667930     271489.0 2014-02-22                 12              6
# 8     79792372943     275108.0 2014-02-22                  3              1
# 9     50076728598     269014.0 2014-02-21                  8              3
#
#    Qty  Rate      Tax  total_amt Store_type
# 0   -5  -772  405.300  -4265.300     e-Shop
# ...

# %%
df1=pd.merge(left=transactions, right=customer , how= 'outer',on='customer_Id')
df1
# Out:
#        transaction_id  customer_Id  tran_date  prod_sub_cat_code  \
# 0        8.071219e+10     270351.0 2014-02-28                1.0
# 1        8.071219e+10     270351.0 2014-02-20                1.0
# 2        3.695744e+10     270351.0 2013-09-16                3.0
# 3        1.223628e+10     270351.0 2013-03-18                8.0
# 4        1.318156e+10     270351.0 2011-12-13                6.0
# ...               ...          ...        ...                ...
# 23189             NaN     270232.0        NaT                NaN
# 23190             NaN     268693.0        NaT                NaN
# 23191             NaN     266947.0        NaT                NaN
# 23192             NaN     270973.0        NaT                NaN
# 23193             NaN     272125.0        NaT                NaN
#
#        prod_cat_code  Qty    Rate      Tax  total_amt      Store_type  \
# 0                1.0 -5.0  -772.0  405.300  -4265.300          e-Shop
# ...

# %%
Customer_Final=pd.merge(df1,productinfo,how='inner')
Customer_Final
# Out:
#        transaction_id  customer_Id  tran_date  prod_sub_cat_code  \
# 0        8.071219e+10     270351.0 2014-02-28                1.0
# 1        8.071219e+10     270351.0 2014-02-20                1.0
# 2        1.850584e+10     271509.0 2013-12-16                1.0
# 3        9.281448e+10     267750.0 2013-08-16                1.0
# 4        9.281448e+10     267750.0 2013-07-08                1.0
# ...               ...          ...        ...                ...
# 23048    7.173864e+09     271157.0 2011-09-04                4.0
# 23049    5.618131e+09     272010.0 2011-03-03                4.0
# 23050    1.872796e+10     267161.0 2011-02-23                4.0
# 23051    6.041681e+10     273281.0 2011-02-18                4.0
# 23052    8.324568e+10     273723.0 2011-01-26                4.0
#
#        prod_cat_code  Qty    Rate      Tax  total_amt      Store_type  \
# 0                1.0 -5.0  -772.0  405.300  -4265.300          e-Shop
# ...

# %%
Customer_Final.dropna(axis=0,inplace=True)
Customer_Final
# Out:
#        transaction_id  customer_Id  tran_date  prod_sub_cat_code  \
# 0        8.071219e+10     270351.0 2014-02-28                1.0
# 1        8.071219e+10     270351.0 2014-02-20                1.0
# 2        1.850584e+10     271509.0 2013-12-16                1.0
# 3        9.281448e+10     267750.0 2013-08-16                1.0
# 4        9.281448e+10     267750.0 2013-07-08                1.0
# ...               ...          ...        ...                ...
# 23048    7.173864e+09     271157.0 2011-09-04                4.0
# 23049    5.618131e+09     272010.0 2011-03-03                4.0
# 23050    1.872796e+10     267161.0 2011-02-23                4.0
# 23051    6.041681e+10     273281.0 2011-02-18                4.0
# 23052    8.324568e+10     273723.0 2011-01-26                4.0
#
#        prod_cat_code  Qty    Rate      Tax  total_amt      Store_type  \
# 0                1.0 -5.0  -772.0  405.300  -4265.300          e-Shop
# ...

# %%
Customer_Final.drop_duplicates(inplace=True)
Customer_Final
# Out:
#        transaction_id  customer_Id  tran_date  prod_sub_cat_code  \
# 0        8.071219e+10     270351.0 2014-02-28                1.0
# 1        8.071219e+10     270351.0 2014-02-20                1.0
# 2        1.850584e+10     271509.0 2013-12-16                1.0
# 3        9.281448e+10     267750.0 2013-08-16                1.0
# 4        9.281448e+10     267750.0 2013-07-08                1.0
# ...               ...          ...        ...                ...
# 23048    7.173864e+09     271157.0 2011-09-04                4.0
# 23049    5.618131e+09     272010.0 2011-03-03                4.0
# 23050    1.872796e+10     267161.0 2011-02-23                4.0
# 23051    6.041681e+10     273281.0 2011-02-18                4.0
# 23052    8.324568e+10     273723.0 2011-01-26                4.0
#
#        prod_cat_code  Qty    Rate      Tax  total_amt      Store_type  \
# 0                1.0 -5.0  -772.0  405.300  -4265.300          e-Shop
# ...

# %%
Customer_Final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23023 entries, 0 to 23052
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   transaction_id     23023 non-null  float64
#  1   customer_Id        23023 non-null  float64
#  2   tran_date          23023 non-null  datetime64[ns]
#  3   prod_sub_cat_code  23023 non-null  float64
#  4   prod_cat_code      23023 non-null  float64
#  5   Qty                23023 non-null  float64
#  6   Rate               23023 non-null  float64
#  7   Tax                23023 non-null  float64
#  8   total_amt          23023 non-null  float64
#  9   Store_type         23023 non-null  object
#  10  DOB                23023 non-null  datetime64[ns]
#  11  Gender             23023 non-null  object
#  12  city_code          23023 non-null  float64
#  13  prod_cat           23023 non-null  object
#  14  prod_subcat        23023 non-null  object
# ...

# %%
Customer_Final.head(10)
# Out:
#    transaction_id  customer_Id  tran_date  prod_sub_cat_code  prod_cat_code  \
# 0    8.071219e+10     270351.0 2014-02-28                1.0            1.0
# 1    8.071219e+10     270351.0 2014-02-20                1.0            1.0
# 2    1.850584e+10     271509.0 2013-12-16                1.0            1.0
# 3    9.281448e+10     267750.0 2013-08-16                1.0            1.0
# 4    9.281448e+10     267750.0 2013-07-08                1.0            1.0
# 5    4.737317e+09     269345.0 2011-07-29                1.0            1.0
# 6    4.442589e+10     274987.0 2012-03-18                1.0            1.0
# 7    9.050134e+10     271817.0 2012-02-19                1.0            1.0
# 8    9.933542e+10     268755.0 2012-12-13                1.0            1.0
# 9    3.503044e+10     268129.0 2011-11-18                1.0            1.0
#
#    Qty    Rate      Tax  total_amt      Store_type        DOB Gender  \
# ...

# %%
Customer_Final.tail(10)
# Out:
#        transaction_id  customer_Id  tran_date  prod_sub_cat_code  \
# 23043    3.387245e+09     269114.0 2011-07-15                4.0
# 23044    7.690646e+10     267940.0 2011-06-15                4.0
# 23045    7.354962e+10     271334.0 2011-05-07                4.0
# 23046    7.533965e+10     274827.0 2011-02-05                4.0
# 23047    6.650927e+09     268110.0 2011-05-04                4.0
# 23048    7.173864e+09     271157.0 2011-09-04                4.0
# 23049    5.618131e+09     272010.0 2011-03-03                4.0
# 23050    1.872796e+10     267161.0 2011-02-23                4.0
# 23051    6.041681e+10     273281.0 2011-02-18                4.0
# 23052    8.324568e+10     273723.0 2011-01-26                4.0
#
#        prod_cat_code  Qty    Rate      Tax  total_amt      Store_type  \
# 23043            4.0  1.0   388.0   40.740    428.740          e-Shop
# 23044            4.0  2.0  1263.0  265.230   2791.230  Flagship store
# ...

# %%
Customer_Final.describe()
# Out:
#        transaction_id    customer_Id  prod_sub_cat_code  prod_cat_code  \
# count    2.302300e+04   23023.000000       23023.000000   23023.000000
# mean     5.006567e+10  271023.477479           6.148677       3.763497
# std      2.898451e+10    2431.354328           3.726186       1.677049
# min      3.268991e+06  266783.000000           1.000000       1.000000
# 25%      2.492136e+10  268937.000000           3.000000       2.000000
# 50%      5.008910e+10  270981.000000           5.000000       4.000000
# 75%      7.532499e+10  273115.500000          10.000000       5.000000
# max      9.998755e+10  275265.000000          12.000000       6.000000
#
#                 Qty          Rate           Tax     total_amt     city_code
# count  23023.000000  23023.000000  23023.000000  23023.000000  23023.000000
# mean       2.435868    637.116840    248.701263   2109.881471      5.483734
# std        2.264415    621.870539    187.196950   2505.929444      2.863422
# ...

# %% [raw]
# #INDIVIDUAL CALCULATIONS

# %%
Min=Customer_Final.total_amt.min()
print(Min)
# Out:
# -8270.925

# %%
Q1=Customer_Final.total_amt.quantile(0.25)
print(Q1)
# Out:
# 762.45

# %%
Median=Customer_Final.total_amt.median()
print(Median)
# Out:
# 1756.95

# %%
Q3=Customer_Final.total_amt.quantile(0.75)
print(Q3)
# Out:
# 3570.255

# %%
Max=Customer_Final.total_amt.max()
print(Max)
# Out:
# 8287.5

# %%
pd.crosstab(index = Customer_Final.prod_cat, columns = Customer_Final.Store_type,
            values = Customer_Final.prod_cat_code,aggfunc='count')
# Out:
# Store_type        Flagship store   MBR  TeleShop  e-Shop
# prod_cat
# Bags                         388   418       410     780
# Books                       1222  1223      1172    2444
# Clothing                     584   626       575    1172
# Electronics                  995   952       945    1999
# Footwear                     574   608       599    1214
# Home and kitchen             810   831       792    1690

# %%
pd.crosstab(index = Customer_Final.prod_subcat, columns = Customer_Final.Store_type,
            values = Customer_Final.prod_cat_code,aggfunc='count')
# Out:
# Store_type           Flagship store  MBR  TeleShop  e-Shop
# prod_subcat
# Academic                        185  206       182     393
# Audio and video                 173  209       170     399
# Bath                            212  204       191     413
# Cameras                         206  194       206     378
# Children                        233  182       196     423
# Comics                          192  211       209     418
# Computers                       200  188       186     382
# DIY                             189  205       206     388
# Fiction                         206  197       214     425
# Furnishing                      193  202       196     415
# Kids                            387  419       416     773
# Kitchen                         212  229       195     400
# Mens                            547  594       591    1177
# Mobiles                         216  179       195     440
# Non-Fiction                     217  222       165     397
# ...

# %%
continous_variables=Customer_Final.loc[ : ,["prod_sub_cat_code","prod_cat_code","Qty","Rate","Tax","total_amt"]]
continous_variables.columns
# Out:
# Index(['prod_sub_cat_code', 'prod_cat_code', 'Qty', 'Rate', 'Tax',
#        'total_amt'],
#       dtype='object')

# %%
for var in continous_variables.columns:
    continous_variables[var].plot(kind='hist')
    plt.title(var)
    plt.show()

# %%
categorical_variables=Customer_Final.loc[ : ,["Store_type","prod_cat","prod_subcat","Gender"]]
categorical_variables.columns
# Out:
# Index(['Store_type', 'prod_cat', 'prod_subcat', 'Gender'], dtype='object')

# %%
plt.figure(figsize=(4,4))
sns.countplot(categorical_variables['Gender'])
plt.show()
# Out:
# C:\Users\Teaswani Sharma\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(4,4))
sns.countplot(categorical_variables['Store_type'])
plt.xlabel('Store Type')
plt.show()
# Out:
# C:\Users\Teaswani Sharma\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(6,6))
sns.countplot(categorical_variables['prod_cat'])
plt.xlabel('Product Category')
plt.show()
# Out:
# C:\Users\Teaswani Sharma\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(8,8))
categorical_variables.groupby('prod_subcat')['prod_subcat'].count().plot(kind='barh')
plt.xlabel('Count')
plt.ylabel('Product Subcategory')
plt.show()

# %%
Customer_Final.sort_values(by='tran_date')
# Out:
#        transaction_id  customer_Id  tran_date  prod_sub_cat_code  \
# 6344     4.947037e+09     271239.0 2011-01-02               12.0
# 19386    8.384947e+10     269958.0 2011-01-02               12.0
# 4823     1.566237e+10     272756.0 2011-01-02                5.0
# 18434    4.262576e+09     267642.0 2011-01-02                1.0
# 15475    3.578999e+10     267508.0 2011-01-02                4.0
# ...               ...          ...        ...                ...
# 6006     1.232385e+10     273552.0 2014-12-02               12.0
# 2084     7.402309e+10     271180.0 2014-12-02                8.0
# 6007     8.921495e+10     273322.0 2014-12-02               12.0
# 13128    3.343387e+10     269772.0 2014-12-02                4.0
# 11199    8.366198e+10     274678.0 2014-12-02               10.0
#
#        prod_cat_code  Qty    Rate      Tax  total_amt      Store_type  \
# 6344             6.0  3.0   228.0   71.820    755.820          e-Shop
# ...

# %%
min_date= Customer_Final["tran_date"].min()
min_date
# Out:
# Timestamp('2011-01-02 00:00:00')

# %%
max_date= Customer_Final["tran_date"].max()
max_date
# Out:
# Timestamp('2014-12-02 00:00:00')

# %%
print(pd.Timestamp.strftime(min_date,format="%d-%m-%Y") + " to "  + pd.Timestamp.strftime(max_date,format="%d-%m-%Y"))
# Out:
# 02-01-2011 to 02-12-2014

# %%
negative_transaction = Customer_Final.loc[Customer_Final["total_amt"] < 0,"transaction_id"].count()
negative_transaction
# Out:
# 2163

# %%
Customer_Final.groupby(['Gender','prod_cat'])[['Qty']].sum().reset_index()
# Out:
#    Gender          prod_cat     Qty
# 0       F              Bags  2364.0
# 1       F             Books  7080.0
# 2       F          Clothing  3425.0
# 3       F       Electronics  5827.0
# 4       F          Footwear  3721.0
# 5       F  Home and kitchen  4898.0
# 6       M              Bags  2345.0
# 7       M             Books  7586.0
# 8       M          Clothing  3748.0
# 9       M       Electronics  6480.0
# 10      M          Footwear  3561.0
# 11      M  Home and kitchen  5046.0

# %%
group1=Customer_Final.groupby('city_code')['customer_Id'].count().sort_values(ascending=False)
group1
# Out:
# city_code
# 4.0     2422
# 3.0     2410
# 5.0     2357
# 7.0     2356
# 10.0    2333
# 8.0     2328
# 2.0     2263
# 1.0     2255
# 9.0     2176
# 6.0     2123
# Name: customer_Id, dtype: int64

# %%
plt.figure(figsize=(8,5))
group1.plot(kind="bar")
plt.xlabel("City Code")
plt.ylabel("No. of customers")
plt.yticks(np.arange(0, 3500, step=500))
plt.show()

# %%
percentage = round((group1[4.0] / group1.sum()) * 100,2)
percentage
# Out:
# 10.52

# %%
Customer_Final.head(5)
# Out:
#    transaction_id  customer_Id  tran_date  prod_sub_cat_code  prod_cat_code  \
# 0    8.071219e+10     270351.0 2014-02-28                1.0            1.0
# 1    8.071219e+10     270351.0 2014-02-20                1.0            1.0
# 2    1.850584e+10     271509.0 2013-12-16                1.0            1.0
# 3    9.281448e+10     267750.0 2013-08-16                1.0            1.0
# 4    9.281448e+10     267750.0 2013-07-08                1.0            1.0
#
#    Qty    Rate      Tax  total_amt      Store_type        DOB Gender  \
# 0 -5.0  -772.0  405.300  -4265.300          e-Shop 1981-09-26      M
# 1  5.0   772.0  405.300   4265.300          e-Shop 1981-09-26      M
# 2  3.0  1229.0  387.135   4074.135  Flagship store 1981-08-06      M
# 3 -4.0  -284.0  119.280  -1255.280  Flagship store 1986-10-13      M
# 4  4.0   284.0  119.280   1255.280  Flagship store 1986-10-13      M
#
#    city_code  prod_cat prod_subcat
# 0        5.0  Clothing       Women
# ...

# %%
Customer_Final.groupby("Store_type")["Qty","Rate"].sum().sort_values(by="Qty",ascending=False)
# Out:
# C:\Users\Teaswani Sharma\AppData\Local\Temp\ipykernel_5820\1483729463.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   Customer_Final.groupby("Store_type")["Qty","Rate"].sum().sort_values(by="Qty",ascending=False)
#                     Qty       Rate
# Store_type
# e-Shop          22785.0  5943931.0
# MBR             11188.0  2951847.0
# Flagship store  11140.0  2942072.0
# TeleShop        10968.0  2830491.0

# %%
store_group = round(Customer_Final.pivot_table(index = "prod_cat",columns="Store_type", values="total_amt", aggfunc='sum'),2)
store_group
# Out:
# Store_type        Flagship store         MBR    TeleShop      e-Shop
# prod_cat
# Bags                   870285.84   848678.68   789181.06  1617933.26
# Books                 2493677.81  2491402.62  2538591.64  5295952.28
# Clothing              1194423.23  1287686.34  1241527.17  2527193.56
# Electronics           2214512.82  2107969.83  1968538.72  4429142.77
# Footwear              1234806.56  1109614.48  1235719.29  2643215.25
# Home and kitchen      1713004.15  1822403.57  1574832.74  3325507.44

# %%
store_group.loc[["Clothing","Electronics"],"Flagship store"]
# Out:
# prod_cat
# Clothing       1194423.23
# Electronics    2214512.82
# Name: Flagship store, dtype: float64

# %%
store_group.loc[["Clothing","Electronics"],"Flagship store"].sum()
# Out:
# 3408936.05

# %%
gender_group = round(Customer_Final.pivot_table(index = "prod_cat",columns="Gender", values="total_amt", aggfunc='sum'),2)
gender_group
# Out:
# Gender                     F           M
# prod_cat
# Bags              2079618.84  2046460.00
# Books             6174590.82  6645033.52
# Clothing          3026750.80  3224079.50
# Electronics       5014292.20  5705871.92
# Footwear          3203155.22  3020200.36
# Home and kitchen  4133702.24  4302045.67

# %%
male_earning = gender_group.loc["Electronics","M"]
male_earning
# Out:
# 5705871.92

# %%
pos_trans = Customer_Final.loc[Customer_Final["total_amt"]>0]
pos_trans
# Out:
#        transaction_id  customer_Id  tran_date  prod_sub_cat_code  \
# 1        8.071219e+10     270351.0 2014-02-20                1.0
# 2        1.850584e+10     271509.0 2013-12-16                1.0
# 4        9.281448e+10     267750.0 2013-07-08                1.0
# 5        4.737317e+09     269345.0 2011-07-29                1.0
# 6        4.442589e+10     274987.0 2012-03-18                1.0
# ...               ...          ...        ...                ...
# 23048    7.173864e+09     271157.0 2011-09-04                4.0
# 23049    5.618131e+09     272010.0 2011-03-03                4.0
# 23050    1.872796e+10     267161.0 2011-02-23                4.0
# 23051    6.041681e+10     273281.0 2011-02-18                4.0
# 23052    8.324568e+10     273723.0 2011-01-26                4.0
#
#        prod_cat_code  Qty    Rate      Tax  total_amt      Store_type  \
# 1                1.0  5.0   772.0  405.300   4265.300          e-Shop
# ...

# %%
unique_trans = pos_trans.groupby(['customer_Id','prod_cat','prod_subcat'])['transaction_id'].count().reset_index()
unique_trans
# Out:
#        customer_Id          prod_cat  prod_subcat  transaction_id
# 0         266783.0             Books  Non-Fiction               1
# 1         266783.0          Clothing         Mens               2
# 2         266783.0          Footwear         Mens               1
# 3         266784.0             Books      Fiction               1
# 4         266784.0             Books  Non-Fiction               1
# ...            ...               ...          ...             ...
# 19257     275264.0             Books  Non-Fiction               1
# 19258     275264.0  Home and kitchen        Tools               1
# 19259     275265.0              Bags         Mens               1
# 19260     275265.0             Books     Academic               1
# 19261     275265.0  Home and kitchen   Furnishing               1
#
# [19262 rows x 4 columns]

# %%
unique_trans_count = unique_trans.groupby('customer_Id')['transaction_id'].count().reset_index()
unique_trans_count.head()
# Out:
#    customer_Id  transaction_id
# 0     266783.0               3
# 1     266784.0               3
# 2     266785.0               5
# 3     266788.0               4
# 4     266794.0               8

# %%
unique_trans_count[unique_trans_count['transaction_id'] > 10]
# Out:
# Empty DataFrame
# Columns: [customer_Id, transaction_id]
# Index: []

# %%
now = pd.Timestamp('now')
Customer_Final['DOB'] = pd.to_datetime(Customer_Final['DOB'], format='%m%d%y')    # 1
Customer_Final['DOB'] = Customer_Final['DOB'].where(Customer_Final['DOB'] < now, Customer_Final['DOB'] -  np.timedelta64(100, 'Y'))   # 2
Customer_Final['AGE'] = (now - Customer_Final['DOB']).astype('<m8[Y]')

# %%
Customer_Final.head(4)
# Out:
#    transaction_id  customer_Id  tran_date  prod_sub_cat_code  prod_cat_code  \
# 0    8.071219e+10     270351.0 2014-02-28                1.0            1.0
# 1    8.071219e+10     270351.0 2014-02-20                1.0            1.0
# 2    1.850584e+10     271509.0 2013-12-16                1.0            1.0
# 3    9.281448e+10     267750.0 2013-08-16                1.0            1.0
#
#    Qty    Rate      Tax  total_amt      Store_type        DOB Gender  \
# 0 -5.0  -772.0  405.300  -4265.300          e-Shop 1981-09-26      M
# 1  5.0   772.0  405.300   4265.300          e-Shop 1981-09-26      M
# 2  3.0  1229.0  387.135   4074.135  Flagship store 1981-06-08      M
# 3 -4.0  -284.0  119.280  -1255.280  Flagship store 1986-10-13      M
#
#    city_code  prod_cat prod_subcat   AGE
# 0        5.0  Clothing       Women  40.0
# 1        5.0  Clothing       Women  40.0
# 2        3.0  Clothing       Women  41.0
# 3        1.0  Clothing       Women  35.0

# %%
Customer_Final['Age_cat'] = pd.cut(Customer_Final['AGE'],bins=[24,35,46,57],labels=['25-35','36-46','47-57'],include_lowest=True)

# %%
Customer_Final.head(10)
# Out:
#    transaction_id  customer_Id  tran_date  prod_sub_cat_code  prod_cat_code  \
# 0    8.071219e+10     270351.0 2014-02-28                1.0            1.0
# 1    8.071219e+10     270351.0 2014-02-20                1.0            1.0
# 2    1.850584e+10     271509.0 2013-12-16                1.0            1.0
# 3    9.281448e+10     267750.0 2013-08-16                1.0            1.0
# 4    9.281448e+10     267750.0 2013-07-08                1.0            1.0
# 5    4.737317e+09     269345.0 2011-07-29                1.0            1.0
# 6    4.442589e+10     274987.0 2012-03-18                1.0            1.0
# 7    9.050134e+10     271817.0 2012-02-19                1.0            1.0
# 8    9.933542e+10     268755.0 2012-12-13                1.0            1.0
# 9    3.503044e+10     268129.0 2011-11-18                1.0            1.0
#
#    Qty    Rate      Tax  total_amt      Store_type        DOB Gender  \
# ...

# %%
customer_25_35 = Customer_Final.groupby(['Age_cat','prod_cat'])['total_amt'].sum()
customer_25_35
# Out:
# Age_cat  prod_cat
# 25-35    Bags                1112732.790
#          Books               3385926.635
#          Clothing            1912558.310
#          Electronics         3057786.940
#          Footwear            1845814.100
#          Home and kitchen    2411281.275
# 36-46    Bags                1937569.985
#          Books               6331942.825
#          Clothing            2937231.440
#          Electronics         4997695.105
#          Footwear            2892555.185
#          Home and kitchen    4086130.880
# 47-57    Bags                1075776.065
#          Books               3101754.890
#          Clothing            1401040.550
#          Electronics         2664682.085
#          Footwear            1484986.295
#          Home and kitchen    1938335.750
# Name: total_amt, dtype: float64

# %%
customer_25_35.loc['25-35',['Books','Electronics']]
# Out:
# Age_cat  prod_cat
# 25-35    Books          3385926.635
#          Electronics    3057786.940
# Name: total_amt, dtype: float64

# %%
customer_25_35.loc['25-35',['Books','Electronics']].sum().round(2)
# Out:
# 6443713.57

# %%
Customer_Final.head(5)
# Out:
#    transaction_id  customer_Id  tran_date  prod_sub_cat_code  prod_cat_code  \
# 0    8.071219e+10     270351.0 2014-02-28                1.0            1.0
# 1    8.071219e+10     270351.0 2014-02-20                1.0            1.0
# 2    1.850584e+10     271509.0 2013-12-16                1.0            1.0
# 3    9.281448e+10     267750.0 2013-08-16                1.0            1.0
# 4    9.281448e+10     267750.0 2013-07-08                1.0            1.0
#
#    Qty    Rate      Tax  total_amt      Store_type        DOB Gender  \
# 0 -5.0  -772.0  405.300  -4265.300          e-Shop 1981-09-26      M
# 1  5.0   772.0  405.300   4265.300          e-Shop 1981-09-26      M
# 2  3.0  1229.0  387.135   4074.135  Flagship store 1981-08-06      M
# 3 -4.0  -284.0  119.280  -1255.280  Flagship store 1986-10-13      M
# 4  4.0   284.0  119.280   1255.280  Flagship store 1986-10-13      M
#
#    city_code  prod_cat prod_subcat   AGE Age_cat
# ...

# %%
customer_total_amount_25_35 = Customer_Final[Customer_Final['Age_cat']=='25-35']
customer_total_amount_25_35.head()
# Out:
#     transaction_id  customer_Id  tran_date  prod_sub_cat_code  prod_cat_code  \
# 3     9.281448e+10     267750.0 2013-08-16                1.0            1.0
# 4     9.281448e+10     267750.0 2013-07-08                1.0            1.0
# 7     9.050134e+10     271817.0 2012-02-19                1.0            1.0
# 11    9.095413e+10     269387.0 2013-03-18                1.0            1.0
# 17    1.199944e+10     268052.0 2012-06-18                1.0            1.0
#
#     Qty    Rate     Tax  total_amt      Store_type        DOB Gender  \
# 3  -4.0  -284.0  119.28   -1255.28  Flagship store 1986-10-13      M
# 4   4.0   284.0  119.28    1255.28  Flagship store 1986-10-13      M
# 7   1.0  1122.0  117.81    1239.81        TeleShop 1989-12-24      M
# 11  4.0   839.0  352.38    3708.38             MBR 1990-03-02      F
# 17  2.0  1324.0  278.04    2926.04  Flagship store 1988-12-18      M
#
#     city_code  prod_cat prod_subcat   AGE Age_cat
# ...

# %%
total_amount = customer_total_amount_25_35[(customer_total_amount_25_35['tran_date'] >='2014-01-01') & (customer_total_amount_25_35['tran_date'] <='2014-03-01')]
total_amount
# Out:
#        transaction_id  customer_Id  tran_date  prod_sub_cat_code  \
# 20       7.371310e+10     268867.0 2014-02-15                1.0
# 23       5.713474e+10     270625.0 2014-02-14                1.0
# 38       6.493923e+10     270240.0 2014-01-29                1.0
# 45       6.558211e+10     267243.0 2014-01-29                1.0
# 63       8.746136e+10     270831.0 2014-01-15                1.0
# ...               ...          ...        ...                ...
# 22198    6.099042e+10     272399.0 2014-01-13                4.0
# 22199    4.769127e+10     272059.0 2014-01-15                4.0
# 22204    3.870260e+10     274594.0 2014-01-14                4.0
# 22206    6.972447e+10     271352.0 2014-01-14                4.0
# 22240    9.205284e+10     267263.0 2014-03-01                4.0
#
#        prod_cat_code  Qty    Rate      Tax  total_amt      Store_type  \
# 20               1.0  1.0   714.0   74.970    788.970             MBR
# ...

# %%
total_amount['total_amt'].sum()
# Out:
# 448123.91
